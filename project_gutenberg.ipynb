# %%
from bs4 import BeautifulSoup as bs
import requests as req
from pprint import pprint
import re #正規表達式模組
import os, json
from time import sleep

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# annotated-types              0.7.0
# anthropic                    0.49.0
# anyio                        4.9.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    3.0.0
# async-lru                    2.0.4
# attrs                        24.3.0
# babel                        2.16.0
# backoff                      2.2.1
# beautifulsoup4               4.12.3
# bleach                       6.2.0
# branca                       0.8.1
# Brotli                       1.0.9
# browser-use                  0.1.40
# cachetools                   5.5.2
# certifi                      2025.1.31
# cffi                         1.17.1
# charset-normalizer           3.3.2
# colorama                     0.4.6
# comm                         0.2.1
# debugpy                      1.8.11
# decorator                    5.1.1
# defusedxml                   0.7.1
# distro                       1.9.0
# executing                    0.8.3
# fastjsonschema               2.20.0
# filetype                     1.2.0
# google-ai-generativelanguage 0.6.17
# google-api-core              2.24.2
# google-auth                  2.39.0
# google-genai                 1.11.0
# googleapis-common-protos     1.70.0
# greenlet                     3.2.0
# grpcio                       1.72.0rc1
# grpcio-status                1.72.0rc1
# h11                          0.14.0
# httpcore                     1.0.2
# httpx                        0.28.1
# idna                         3.7
# ipykernel                    6.29.5
# ipyleaflet                   0.19.2
# ipython                      8.30.0
# ipywidgets                   8.1.6
# jedi                         0.19.2
# Jinja2                       3.1.6
# jiter                        0.9.0
# json5                        0.9.25
# jsonpatch                    1.33
# jsonpointer                  3.0.0
# jsonschema                   4.23.0
# jsonschema-specifications    2023.7.1
# jupyter_client               8.6.3
# jupyter_core                 5.7.2
# jupyter-events               0.12.0
# jupyter-leaflet              0.19.2
# jupyter-lsp                  2.2.0
# jupyter_server               2.15.0
# jupyter_server_terminals     0.4.4
# jupyterlab                   4.3.4
# jupyterlab_pygments          0.3.0
# jupyterlab_server            2.27.3
# jupyterlab_widgets           3.0.14
# langchain-anthropic          0.3.3
# langchain-core               0.3.54
# langchain-google-genai       2.1.3
# langchain-ollama             0.2.2
# langchain-openai             0.3.1
# langsmith                    0.3.32
# lxml                         5.3.2
# markdownify                  0.14.1
# MarkupSafe                   3.0.2
# matplotlib-inline            0.1.6
# mistune                      3.1.2
# monotonic                    1.6
# nbclient                     0.10.2
# nbconvert                    7.16.6
# nbformat                     5.10.4
# nest-asyncio                 1.6.0
# notebook                     7.3.2
# notebook_shim                0.2.4
# ollama                       0.4.8
# openai                       1.75.0
# orjson                       3.10.16
# outcome                      1.3.0.post0
# overrides                    7.4.0
# packaging                    24.2
# pandocfilters                1.5.0
# parso                        0.8.4
# pip                          25.0
# platformdirs                 4.3.7
# playwright                   1.51.0
# posthog                      3.25.0
# prometheus_client            0.21.1
# prompt-toolkit               3.0.43
# proto-plus                   1.26.1
# protobuf                     6.30.2
# psutil                       5.9.0
# pure-eval                    0.2.2
# pyasn1                       0.6.1
# pyasn1_modules               0.4.2
# pycparser                    2.21
# pydantic                     2.11.3
# pydantic_core                2.33.1
# pyee                         12.1.1
# Pygments                     2.15.1
# PySocks                      1.7.1
# python-dateutil              2.9.0.post0
# python-dotenv                1.1.0
# python-json-logger           3.2.1
# pywin32                      308
# pywinpty                     2.0.15
# PyYAML                       6.0.2
# pyzmq                        26.2.0
# referencing                  0.30.2
# regex                        2024.11.6
# requests                     2.32.3
# requests-toolbelt            1.0.0
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rpds-py                      0.22.3
# rsa                          4.9.1
# selenium                     4.31.0
# Send2Trash                   1.8.2
# setuptools                   75.8.0
# six                          1.17.0
# sniffio                      1.3.0
# sortedcontainers             2.4.0
# soupsieve                    2.5
# stack-data                   0.2.0
# tenacity                     9.1.2
# terminado                    0.17.1
# tiktoken                     0.9.0
# tinycss2                     1.4.0
# tornado                      6.4.2
# tqdm                         4.67.1
# traitlets                    5.14.3
# traittypes                   0.2.1
# trio                         0.29.0
# trio-websocket               0.12.2
# typing_extensions            4.12.2
# typing-inspection            0.4.0
# urllib3                      2.3.0
# wcwidth                      0.2.5
# webdriver-manager            4.0.2
# webencodings                 0.5.1
# websocket-client             1.8.0
# websockets                   15.0.1
# wget                         3.2
# wheel                        0.45.1
# widgetsnbextension           4.0.14
# win-inet-pton                1.1.0
# wsproto                      1.2.0
# xyzservices                  2025.1.0
# zstandard                    0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
folderPath = 'project_gutenberg'
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

url = "https://www.gutenberg.org/browse/languages/zh#a32292"

res = req.get(url)

soup = bs(res.text, "lxml")

base = 'https://www.gutenberg.org/'

list_chinese_books = []

# %%
list_chinese_books.clear()

pattern = re.compile(r'[\u4E00-\u9FFF]')

for a in soup.select('body > div.container > div.page_content > div.pgdbbylanguage > ul > li.pgdbetext > a[href^="/ebooks"]'):
    text = a.get_text(strip=True)
    if not pattern.search(text):
        continue       

    list_chinese_books.append({'title': a.get_text(),
                           'link': 'https://www.gutenberg.org' + a['href']
                           })

print(list_chinese_books)
print(f'總共抓到了 {len(list_chinese_books)} 本書')
# Out:
# [{'title': '豆棚閒話', 'link': 'https://www.gutenberg.org/ebooks/25328'}, {'title': '戲中戲', 'link': 'https://www.gutenberg.org/ebooks/24225'}, {'title': '比目魚', 'link': 'https://www.gutenberg.org/ebooks/24185'}, {'title': '比目魚', 'link': 'https://www.gutenberg.org/ebooks/27119'}, {'title': '三字經', 'link': 'https://www.gutenberg.org/ebooks/12479'}, {'title': '山水情', 'link': 'https://www.gutenberg.org/ebooks/25146'}, {'title': '山海經', 'link': 'https://www.gutenberg.org/ebooks/25288'}, {'title': '施公案', 'link': 'https://www.gutenberg.org/ebooks/23825'}, {'title': '施公案', 'link': 'https://www.gutenberg.org/ebooks/25393'}, {'title': '易經', 'link': 'https://www.gutenberg.org/ebooks/25501'}, {'title': '木蘭奇女傳', 'link': 'https://www.gutenberg.org/ebooks/23938'}, {'title': '海公案', 'link': 'https://www.gutenberg.org/ebooks/54494'}, {'title': '燕丹子', 'link': 'https://www.gutenberg.org/ebooks/24068'}, {'title': '狄公案', 'link': 'https://www.gutenberg.org/ebooks/27686'}, {'title': '百家姓', 'link': 'https://www.gutenberg.org/ebooks/25196'}, {'title': '禮記', 'link': 'https://www.gutenberg.org/ebooks/24048'}, {'title': '綠牡丹', 'link': 'https://www.gutenberg.org/ebooks/27330'}, {'title': '詩經', 'link': 'https://www.gutenberg.org/ebooks/23873'}, {'title': '麟兒報', 'link': 'https://www.gutenberg.org/ebooks/27399'}, {'title': '天豹圖', 'link': 'https://www.gutenberg.org/ebooks/26904'}, {'title': '梁公九諫', 'link': 'https://www.gutenberg.org/ebooks/26886'}, {'title': '長恨歌', 'link': 'https://www.gutenberg.org/ebooks/25352'}, {'title': '李娃傳', 'link': 'https://www.gutenberg.org/ebooks/24051'}, {'title': '玉樓春', 'link': 'https://www.gutenberg.org/ebooks/25422'}, {'title': '漢書', 'link': 'https://www.gutenberg.org/ebooks/23841'}, {'title': '引鳳蕭', 'link': 'https://www.gutenberg.org/ebooks/26921'}, {'title': '今古奇觀', 'link': 'https://www.gutenberg.org/ebooks/24230'}, {'title': '後西游記', 'link': 'https://www.gutenberg.org/ebooks/27332'}, {'title': '飛跎全傳', 'link': 'https://www.gutenberg.org/ebooks/27331'}, {'title': '佛說四十二章經', 'link': 'https://www.gutenberg.org/ebooks/23585'}, {'title': '紅樓夢', 'link': 'https://www.gutenberg.org/ebooks/24264'}, {'title': '洛神賦', 'link': 'https://www.gutenberg.org/ebooks/24041'}, {'title': '晁氏儒言 一卷', 'link': 'https://www.gutenberg.org/ebooks/43014'}, {'title': '水滸後傳', 'link': 'https://www.gutenberg.org/ebooks/25217'}, {'title': '幼學瓊林', 'link': 'https://www.gutenberg.org/ebooks/52269'}, {'title': '治世餘聞', 'link': 'https://www.gutenberg.org/ebooks/26932'}, {'title': '琵琶記', 'link': 'https://www.gutenberg.org/ebooks/25246'}, {'title': '雪月梅傳', 'link': 'https://www.gutenberg.org/ebooks/26739'}, {'title': '龍川詞', 'link': 'https://www.gutenberg.org/ebooks/26873'}, {'title': '三國志', 'link': 'https://www.gutenberg.org/ebooks/25606'}, {'title': '隋唐演義', 'link': 'https://www.gutenberg.org/ebooks/23835'}, {'title': '論語', 'link': 'https://www.gutenberg.org/ebooks/23839'}, {'title': '滬語開路 = Conversational Exercises in the Shanghai Dialect', 'link': 'https://www.gutenberg.org/ebooks/62791'}, {'title': '白圭志', 'link': 'https://www.gutenberg.org/ebooks/27023'}, {'title': '孟子字義疏證', 'link': 'https://www.gutenberg.org/ebooks/25360'}, {'title': '安樂集', 'link': 'https://www.gutenberg.org/ebooks/24106'}, {'title': '鄧析子', 'link': 'https://www.gutenberg.org/ebooks/7215'}, {'title': '醉醒石', 'link': 'https://www.gutenberg.org/ebooks/24027'}, {'title': '唐鍾馗平鬼傳', 'link': 'https://www.gutenberg.org/ebooks/27329'}, {'title': '春秋繁露', 'link': 'https://www.gutenberg.org/ebooks/25385'}, {'title': '虬髯客傳', 'link': 'https://www.gutenberg.org/ebooks/23915'}, {'title': '吳船錄', 'link': 'https://www.gutenberg.org/ebooks/27581'}, {'title': '星槎勝覽', 'link': 'https://www.gutenberg.org/ebooks/24143'}, {'title': '星槎勝覽', 'link': 'https://www.gutenberg.org/ebooks/23982'}, {'title': '喻世明言', 'link': 'https://www.gutenberg.org/ebooks/27582'}, {'title': '平妖傳', 'link': 'https://www.gutenberg.org/ebooks/57227'}, {'title': '東周列國志', 'link': 'https://www.gutenberg.org/ebooks/25349'}, {'title': '警世通言', 'link': 'https://www.guten ...
# 總共抓到了 478 本書

# %%
def clean_title(raw_title: str) -> str:
    # 1) 移除換行、跳脫字元
    s = raw_title.replace('\r', '').replace('\n', '').strip()
    # 2) 再把 Windows 檔名不允許的字元也去掉
    return re.sub(r'[<>:"/\\|?*]', '', s)

for idx, book in enumerate(list_chinese_books):
    # 1. 先抓 ebook 主頁面
    resp = req.get(book['link'])
    resp.encoding = resp.apparent_encoding
    soup = bs(resp.text, "lxml")
    
    # 2. 找到那個 Read now! 的連結
    read_content = soup.select_one('a.link.read_html')
    if not read_content:
        print(f"{book['title']} 沒有線上閱讀連結")
        continue
    # 3. 建立完整的線上閱讀 URL
    read_url = base + read_content['href']
    list_chinese_books[idx]['read_url'] = read_url 
    
    # 再從這個 dict 取出 read_url
    # 簡單去掉控制字元（換行、跳脫字元等）和 Windows 禁用字元

    # 最後才對那個 URL 發 GET 請求
    read_url = book['read_url']
    resp2 = req.get(read_url)
    resp2.raise_for_status() # 如果有 HTTP 錯誤會拋例外
    resp2.encoding = resp2.apparent_encoding # 設定正確編碼，避免亂碼
    html = resp2.text
    soup2 = bs(html, 'lxml')

    for head in soup2.select('head'):
        head.decompose()

    for body in soup2.select('body>section.pg-boilerplate'):
        body.decompose()

    for p in soup2.select('body > p[id="id00000"]'):
        p.decompose()

    content = str(soup2.select('body>p'))

    chinese_only = re.sub(r"[^\u4E00-\u9FFF]+", "", content)

    # 取出乾淨的標題
    raw_title = book['title']
    safe_title = clean_title(raw_title)
    filename = os.path.join('project_gutenberg', f"{safe_title}.txt")
    # 寫入檔案 (這裡示範把 chinese_only 寫進去)
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(chinese_only)
    
    print(f"已寫入：{filename}")

   
# print(list_chinese_books)
print(len(list_chinese_books))
# Out:
# 已寫入：project_gutenberg\豆棚閒話.txt
# 已寫入：project_gutenberg\戲中戲.txt
# 已寫入：project_gutenberg\比目魚.txt
# 已寫入：project_gutenberg\比目魚.txt
# 已寫入：project_gutenberg\三字經.txt
# 已寫入：project_gutenberg\山水情.txt
# 已寫入：project_gutenberg\山海經.txt
# 已寫入：project_gutenberg\施公案.txt
# 已寫入：project_gutenberg\施公案.txt
# 已寫入：project_gutenberg\易經.txt
# 已寫入：project_gutenberg\木蘭奇女傳.txt
# 已寫入：project_gutenberg\海公案.txt
# 已寫入：project_gutenberg\燕丹子.txt
# 已寫入：project_gutenberg\狄公案.txt
# 已寫入：project_gutenberg\百家姓.txt
# 已寫入：project_gutenberg\禮記.txt
# 已寫入：project_gutenberg\綠牡丹.txt
# 已寫入：project_gutenberg\詩經.txt
# 已寫入：project_gutenberg\麟兒報.txt
# 已寫入：project_gutenberg\天豹圖.txt
# 已寫入：project_gutenberg\梁公九諫.txt
# 已寫入：project_gutenberg\長恨歌.txt
# 已寫入：project_gutenberg\李娃傳.txt
# 已寫入：project_gutenberg\玉樓春.txt
# 已寫入：project_gutenberg\漢書.txt
# 已寫入：project_gutenberg\引鳳蕭.txt
# 已寫入：project_gutenberg\今古奇觀.txt
# 已寫入：project_gutenberg\後西游記.txt
# 已寫入：project_gutenberg\飛跎全傳.txt
# 已寫入：project_gutenberg\佛說四十二章經.txt
# 已寫入：project_gutenberg\紅樓夢.txt
# 已寫入：project_gutenberg\洛神賦.txt
# 已寫入：project_gutenberg\晁氏儒言 一卷.txt
# 已寫入：project_gutenberg\水滸後傳.txt
# 已寫入：project_gutenberg\幼學瓊林.txt
# 已寫入：project_gutenberg\治世餘聞.txt
# 已寫入：project_gutenberg\琵琶記.txt
# 已寫入：project_gutenberg\雪月梅傳.txt
# 已寫入：project_gutenberg\龍川詞.txt
# 已寫入：project_gutenberg\三國志.txt
# 已寫入：project_gutenberg\隋唐演義.txt
# 已寫入：project_gutenberg\論語.txt
# 已寫入：project_gutenberg\滬語開路 = Conversational Exercises in the Shanghai Dialect.txt
# 已寫入：project_gutenberg\白圭志.txt
# 已寫入：project_gutenberg\孟子字義疏證.txt
# 已寫入：project_gutenberg\安樂集.txt
# 已寫入：project_gutenberg\鄧析子.txt
# 已寫入：project_gutenberg\醉醒石.txt
# 已寫入：project_gutenberg\唐鍾馗平鬼傳.txt
# 已寫入：project_gutenberg\春秋繁露.txt
# 已寫入：project_gutenberg\虬髯客傳.txt
# 已寫入：project_gutenberg\吳船錄.txt
# 已寫入：project_gutenberg\星槎勝覽.txt
# 已寫入：project_gutenberg\星槎勝覽.txt
# 已寫入：project_gutenberg\喻世明言.txt
# 已寫入：project_gutenberg\平妖傳.txt
# 已寫入：project_gutenberg\東周列國志.txt
# 已寫入：project_gutenberg\警世通言.txt
# 已寫入：project_gutenberg\醒世恆言.txt
# 已寫入：project_gutenberg\封氏聞見記.txt
# 已寫入：project_gutenberg\白圭志.txt
# 已寫入：project_gutenberg\搜神記.txt
# 已寫入：project_gutenberg\搜神記 volume 11-14.txt
# 已寫入：project_gutenberg\搜神記 volume 1-3.txt
# 已寫入：project_gutenberg\搜神記 volume 15-17.txt
# 已寫入：project_gutenberg\搜神記 volume 18-20.txt
# 已寫入：project_gutenberg\搜神記 volume 4-10.txt
# 已寫入：project_gutenberg\琵琶記.txt
# 已寫入：project_gutenberg\抱朴子.txt
# 已寫入：project_gutenberg\西京雜記.txt
# 已寫入：project_gutenberg\幽明錄.txt
# 已寫入：project_gutenberg\明鏡公案.txt
# 已寫入：project_gutenberg\公孫龍子.txt
# 已寫入：project_gutenberg\竇娥冤.txt
# 已寫入：project_gutenberg\竇娥寃.txt
# 已寫入：project_gutenberg\管子.txt
# 已寫入：project_gutenberg\管子 — Volume 01  Chapters 1-5.txt
# 已寫入：project_gutenberg\管子 — Volume 02  Chapters 6-10.txt
# 已寫入：project_gutenberg\鬼谷子.txt
# 已寫入：project_gutenberg\鬼谷子.txt
# 已寫入：project_gutenberg\穆天子传.txt
# 已寫入：project_gutenberg\漢武帝別國洞冥記.txt
# 已寫入：project_gutenberg\日知錄.txt
# 已寫入：project_gutenberg\海上花列傳.txt
# 已寫入：project_gutenberg\韩非子.txt
# 已寫入：project_gutenberg\風月夢.txt
# 已寫入：project_gutenberg\韓詩外傳.txt
# 已寫入：project_gutenberg\韓詩外傳, Complete.txt
# 已寫入：project_gutenberg\韓詩外傳, Vol. 1-2.txt
# 已寫入：project_gutenberg\韓詩外傳, Vol. 3-4.txt
# 已寫入：project_gutenberg\韓詩外傳, Vol. 5-6.txt
# 已寫入：project_gutenberg\韓詩外傳, Vol. 7-8.txt
# 已寫入：project_gutenberg\韓詩外傳, Vol. 9-10.txt
# 已寫入：project_gutenberg\唐诗三百首.txt
# 已寫入：project_gutenberg\長生殿.txt
# 已寫入：project_gutenberg\菜根譚.txt
# 已寫入：project_gutenberg\菜根譚前後集.txt
# 已寫入：project_gutenberg\天豹圖.txt
# 已寫入：project_gutenberg\筠州黃檗山斷際禪師傳法心要.txt
# 已寫入：project_gutenberg\山水小牘.txt
# 已寫入：project_gutenberg\高士傳.txt
# 已寫入：project_gutenberg\金剛般若波羅蜜經.txt
# 已寫入：project_gutenberg\天妃顯聖錄.txt
# 已寫入：project_gutenberg\三略.txt
# 已寫入：project_gutenberg\明夷待訪錄.txt
# 已寫入：project_gutenberg\鹽鐵論.txt
# 已寫入：project_gutenberg\一枕奇.txt
# 已寫入：project_gutenberg\六祖壇經.txt
# 已寫入：project_gutenberg\臺灣外紀.txt
# 已寫入：project_gutenberg\賈誼新書.txt
# 已寫入：project_gutenberg\金石緣.txt
# 已寫入：project_gutenberg\閱微草堂筆記.txt
# 已寫入：project_gutenberg\醒夢駢言.txt
# 已寫入：project_gutenberg\孔叢子.txt
# 已寫入：project_gutenberg\小爾雅.txt
# 已寫入：project_gutenberg\續世說.txt
# 已寫入：project_gutenberg\桃花扇.txt
# 已寫入：project_gutenberg\金剛般若波羅蜜經.txt
# 已寫入：project_gutenberg\補紅樓夢.txt
# 已寫入：project_gutenberg\老子.txt
# 已寫入：project_gutenberg\道德經.txt
# 已寫入：project_gutenberg\臺灣通史唐山過海的故事.txt
# 已寫入：project_gutenberg\李太白集.txt
# 已寫入：project_gutenberg\李太白集.txt
# 已寫入：project_gutenberg\官場現形記.txt
# 已寫入：project_gutenberg\官場現形記.txt
# 已寫入：project_gutenberg\官場現形記.txt
# 已寫入：project_gutenberg\文明小史.txt
# 已寫入：project_gutenberg\海公案.txt
# 已寫入：project_gutenberg\孫子算經.txt
# 已寫入：project_gutenberg\列子.txt
# 已寫入：project_gutenberg\脾胃論.txt
# 已寫入：project_gutenberg\李賀詩選.txt
# 已寫入：project_gutenberg\文心雕龍.txt
# 已寫入：project_gutenberg\二刻拍案惊奇.txt
# 已寫入：project_gutenberg\二刻拍案驚奇.txt
# 已寫入：project_gutenberg\初刻拍案驚奇.txt
# 已寫入：project_gutenberg\殺子報.txt
# 已寫入：project_gutenberg\天妃顯聖錄.txt
# 已寫入：project_gutenberg\西海紀遊草.txt
# 已寫入：project_gutenberg\西海紀遊草.txt
# 已寫入：project_gutenberg\漱玉詞.txt
# 已寫入：project_gutenberg\鏡花緣.txt
# 已寫入：project_gutenberg\鏡花緣.txt
# 已寫入：project_gutenberg\李義山詩集.txt
# 已寫入：project_gutenberg\天豹圖.txt
# 已寫入：project_gutenberg\梁公九諫.txt
# 已寫入：project_gutenberg\淮南子.txt
# 已寫入：project_gutenberg\天豹圖.txt
# 已寫入：project_gutenberg\老殘遊記.txt
# 已寫入：project_gutenberg\老殘遊記.txt
# 已寫入：project_gutenberg\老殘遊記續集.txt
# 已寫入：project_gutenberg\海島算經.txt
# 已寫入：project_gutenberg\郁離子.txt
# 已寫入：project_gutenberg\人物志.txt
# 已寫入：project_gutenberg\隋唐嘉話.txt
# 已寫入：project_gutenberg\大唐新語.txt
# 已寫入：project_gutenberg\列仙傳.txt
# 已寫入：project_gutenberg\列女傳.txt
# 已寫入：project_gutenberg\新序.txt
# 已寫入：project_gutenberg\說苑.txt
# 已寫入：project_gutenberg\說苑, Volume 13-16.txt
# 已寫入：project_gutenberg\說苑, Volume 1-4.txt
# 已寫入：project_gutenberg\說苑, Volume 17-20.txt
# 已寫入：project_gutenberg\說苑, Volume 5-8.txt
# 已寫入：project_gutenberg\說苑, Volume 9-12.txt
# 已寫入：project_gutenberg\文心雕龍.txt
# 已寫入：project_gutenberg\西京雜記.txt
# 已寫入：project_gutenberg\舊唐書.txt
# 已寫入：project_gutenberg\世說新語.txt
# 已寫入：project_gutenberg\幽明錄.txt
# 已寫入：project_gutenberg\樂章集.txt
# 已寫入：project_gutenberg\斬鬼傳.txt
# 已寫入：project_gutenberg\斬鬼傳.txt
# 已寫入：project_gutenberg\夢中緣.txt
# 已寫入：project_gutenberg\合錦回文傳.txt
# 已寫入：project_gutenberg\無聲戲.txt
# 已寫入：project_gutenberg\肉蒲團.txt
# 已寫入：project_gutenberg\閒情偶寄.txt
# 已寫入：project_gutenberg\闲情偶寄.txt
# 已寫入：project_gutenberg\弟子規.txt
# 已寫入：project_gutenberg\天豹圖.txt
# 已寫入：project_gutenberg\庚巳編.txt
# 已寫入：project_gutenberg\呻吟語.txt
# 已寫入：project_gutenberg\三國志演義.txt
# 已寫入：project_gutenberg\平妖傳.txt
# 已寫入：project_gutenberg\平妖傳.txt
# 已寫入：project_gutenberg\殘唐五代史演義傳.txt
# 已寫入：project_gutenberg\粉妝樓.txt
# 已寫入：project_gutenberg\粉妝樓1-10回.txt
# 已寫入：project_gutenberg\粉妝樓11-20回.txt
# 已寫入：project_gutenberg\粉妝樓21-30回.txt
# 已寫入：project_gutenberg\粉妝樓31-40回.txt
# 已寫入：project_gutenberg\粉妝樓41-50回.txt
# 已寫入：project_gutenberg\粉妝樓51-60回.txt
# 已寫入：project_gutenberg\粉妝樓61-70回.txt
# 已寫入：project_gutenberg\粉妝樓71-80回.txt
# 已寫入：project_gutenberg\粉妝樓全傳.txt
# 已寫入：project_gutenberg\說唐.txt
# 已寫入：project_gutenberg\文心雕龍.txt
# 已寫入：project_gutenberg\常言道.txt
# 已寫入：project_gutenberg\大唐三藏取經詩話.txt
# 已寫入：project_gutenberg\六韜.txt
# 已寫入：project_gutenberg\癡人說夢記.txt
# 已寫入：project_gutenberg\癡人說夢記.txt
# 已寫入：project_gutenberg\封神演義.txt
# 已寫入：project_gutenberg\中國小說史略.txt
# 已寫入：project_gutenberg\南腔北調集.txt
# 已寫入：project_gutenberg\吶喊.txt
# 已寫入：project_gutenberg\徬徨.txt
# 已寫入：project_gutenberg\朝花夕拾.txt
# 已寫入：project_gutenberg\狂人日記.txt
# 已寫入：project_gutenberg\狂人日記.txt
# 已寫入：project_gutenberg\野草.txt
# 已寫入：project_gutenberg\阿Ｑ正傳.txt
# 已寫入：project_gutenberg\文子.txt
# 已寫入：project_gutenberg\老學庵筆記.txt
# 已寫入：project_gutenberg\茶經.txt
# 已寫入：project_gutenberg\茶經.txt
# 已寫入：project_gutenberg\近思錄.txt
# 已寫入：project_gutenberg\瀛涯勝覽.txt
# 已寫入：project_gutenberg\瀛涯勝覽.txt
# 已寫入：project_gutenberg\漢宮秋.txt
# 已寫入：project_gutenberg\孟子.txt
# 已寫入：project_gutenberg\東京夢華錄.txt
# 已寫入：project_gutenberg\白兔記.txt
# 已寫入：project_gutenberg\好逑傳.txt
# 已寫入：project_gutenberg\御製廣寒殿記.txt
# 已寫入：project_gutenberg\墨子.txt
# 已寫入：project_gutenberg\西湖佳話.txt
# 已寫入：project_gutenberg\癡人福.txt
# 已寫入：project_gutenberg\公墓.txt
# 已寫入：project_gutenberg\飲水詞集.txt
# 已寫入：project_gutenberg\春柳鶯.txt
# 已寫入：project_gutenberg\六一詞.txt
# 已寫入：project_gutenberg\歸田錄.txt
# 已寫入：project_gutenberg\三國志.txt
# 已寫入：project_gutenberg\蜀碧.txt
# 已寫入：project_gutenberg\九尾狐.txt
# 已寫入：project_gutenberg\聊齋志異.txt
# 已寫入：project_gutenberg\醒世姻緣.txt
# 已寫入：project_gutenberg\南部新書.txt
# 已寫入：project_gutenberg\東度記.txt
# 已寫入：project_gutenberg\金雲翹傳.txt
# 已寫入：project_gutenberg\拾遺記.txt
# 已寫入：project_gutenberg\負曝閒談.txt
# 已寫入：project_gutenberg\滬語開路 = Conversational Exercises in the Shanghai Dialect.txt
# 已寫入：project_gutenberg\燕子箋.txt
# 已寫入：project_gutenberg\佛說無量壽經.txt
# 已寫入：project_gutenberg\蕉葉帕.txt
# 已寫入：project_gutenberg\商君書.txt
# 已寫入：project_gutenberg\商子.txt
# 已寫入：project_gutenberg\俗話傾談.txt
# 已寫入：project_gutenberg\慎子.txt
# 已寫入：project_gutenberg\浮生六記.txt
# 已寫入：project_gutenberg\枕中記.txt
# 已寫入：project_gutenberg\夢溪筆談.txt
# 已寫入：project_gutenberg\夢溪筆談, Volume 01-06.txt
# 已寫入：project_gutenberg\夢溪筆談, Volume 01-26.txt
# 已寫入：project_gutenberg\夢溪筆談, Volume 07-10.txt
# 已寫入：project_gutenberg\夢溪筆談, Volume 11-16.txt
# 已寫入：project_gutenberg\夢溪筆談, Volume 17-21.txt
# 已寫入：project_gutenberg\夢溪筆談, Volume 22-26.txt
# 已寫入：project_gutenberg\諧鐸.txt
# 已寫入：project_gutenberg\六祖壇經.txt
# 已寫入：project_gutenberg\幽閨記.txt
# 已寫入：project_gutenberg\水滸傳.txt
# 已寫入：project_gutenberg\文子.txt
# 已寫入：project_gutenberg\三俠五義.txt
# 已寫入：project_gutenberg\史記.txt
# 已寫入：project_gutenberg\司馬法.txt
# 已寫入：project_gutenberg\灵历集光.txt
# 已寫入：project_gutenberg\灵历集光.txt
# 已寫入：project_gutenberg\莊子的故事.txt
# 已寫入：project_gutenberg\天工開物.txt
# 已寫入：project_gutenberg\歸蓮夢.txt
# 已寫入：project_gutenberg\錦香亭.txt
# 已寫入：project_gutenberg\杜陽雜編.txt
# 已寫入：project_gutenberg\斷鴻零雁記.txt
# 已寫入：project_gutenberg\北夢瑣言.txt
# 已寫入：project_gutenberg\兵法 (Bīng Fǎ).txt
# 已寫入：project_gutenberg\孫子兵法.txt
# 已寫入：project_gutenberg\孫子算經.txt
# 已寫入：project_gutenberg\東坡志林.txt
# 已寫入：project_gutenberg\東坡樂府.txt
# 已寫入：project_gutenberg\水調歌頭.txt
# 已寫入：project_gutenberg\蘇洵集.txt
# 已寫入：project_gutenberg\孫子兵法道家新註解.txt
# 已寫入：project_gutenberg\牡丹亭.txt
# 已寫入：project_gutenberg\彭公案.txt
# 已寫入：project_gutenberg\五孝傳.txt
# 已寫入：project_gutenberg\搜神後記.txt
# 已寫入：project_gutenberg\搜神後記. Selections. 1985.txt
# 已寫入：project_gutenberg\轟天雷.txt
# 已寫入：project_gutenberg\人間樂.txt
# 已寫入：project_gutenberg\定情人.txt
# 已寫入：project_gutenberg\平山冷燕.txt
# 已寫入：project_gutenberg\玉嬌梨.txt
# 已寫入：project_gutenberg\玉支机.txt
# 已寫入：project_gutenberg\玉雙魚.txt
# 已寫入：project_gutenberg\畫圖緣.txt
# 已寫入：project_gutenberg\石點頭.txt
# 已寫入：project_gutenberg\商界現形記.txt
# 已寫入：project_gutenberg\合錦回文傳.txt
# 已寫入：project_gutenberg\玉蟾記.txt
# 已寫入：project_gutenberg\宋史.txt
# 已寫入：project_gutenberg\周髀算經.txt
# 已寫入：project_gutenberg\天豹圖.txt
# 已寫入：project_gutenberg\孔雀東南飛.txt
# 已寫入：project_gutenberg\孝經.txt
# 已寫入：project_gutenberg\文子.txt
# 已寫入：project_gutenberg\明鏡公案.txt
# 已寫入：project_gutenberg\春秋配.txt
# 已寫入：project_gutenberg\梁公九諫.txt
# 已寫入：project_gutenberg\爾雅.txt
# 已寫入：project_gutenberg\竹書紀年.txt
# 已寫入：project_gutenberg\黄帝宅經.txt
# 已寫入：project_gutenberg\大唐三藏取經詩話.txt
# 已寫入：project_gutenberg\文淵閣四庫全書.txt
# 已寫入：project_gutenberg\本草備要.txt
# 已寫入：project_gutenberg\論衡.txt
# 已寫入：project_gutenberg\魏鄭公諫錄.txt
# 已寫入：project_gutenberg\人間詞話.txt
# 已寫入：project_gutenberg\大唐三藏取經詩話.txt
# 已寫入：project_gutenberg\海國春秋.txt
# 已寫入：project_gutenberg\拾遺記.txt
# 已寫入：project_gutenberg\冷眼观.txt
# 已寫入：project_gutenberg\竹齋集.txt
# 已寫入：project_gutenberg\西廂記.txt
# 已寫入：project_gutenberg\豔異編.txt
# 已寫入：project_gutenberg\分甘余話.txt
# 已寫入：project_gutenberg\劍俠傳.txt
# 已寫入：project_gutenberg\池北偶談.txt
# 已寫入：project_gutenberg\文中子中說.txt
# 已寫入：project_gutenberg\荀子集解.txt
# 已寫入：project_gutenberg\醒夢駢言.txt
# 已寫入：project_gutenberg\豆棚閒話.txt
# 已寫入：project_gutenberg\傳習錄.txt
# 已寫入：project_gutenberg\王陽明全集.txt
# 已寫入：project_gutenberg\故事新讀本 第一冊.txt
# 已寫入：project_gutenberg\三字經.txt
# 已寫入：project_gutenberg\花外集.txt
# 已寫入：project_gutenberg\圍爐夜話.txt
# 已寫入：project_gutenberg\文中子中說.txt
# 已寫入：project_gutenberg\御製廣寒殿記.txt
# 已寫入：project_gutenberg\尉繚子.txt
# 已寫入：project_gutenberg\花月痕.txt
# 已寫入：project_gutenberg\花月痕.txt
# 已寫入：project_gutenberg\明月台.txt
# 已寫入：project_gutenberg\兒女英雄傳.txt
# 已寫入：project_gutenberg\玉壺淸話.txt
# 已寫入：project_gutenberg\西遊記.txt
# 已寫入：project_gutenberg\古文觀止.txt
# 已寫入：project_gutenberg\青箱雜記.txt
# 已寫入：project_gutenberg\古文觀止.txt
# 已寫入：project_gutenberg\海遊記.txt
# 已寫入：project_gutenberg\駐春園小史.txt
# 已寫入：project_gutenberg\九命奇冤.txt
# 已寫入：project_gutenberg\九命奇冤.txt
# 已寫入：project_gutenberg\二十年目睹之怪現狀.txt
# 已寫入：project_gutenberg\二十年目睹之怪現狀.txt
# 已寫入：project_gutenberg\恨海.txt
# 已寫入：project_gutenberg\情變.txt
# 已寫入：project_gutenberg\瞎騙奇聞.txt
# 已寫入：project_gutenberg\胡涂世界.txt
# 已寫入：project_gutenberg\貞觀政要.txt
# 已寫入：project_gutenberg\貞觀政要.txt
# 已寫入：project_gutenberg\中國十大禁書之國色天香.txt
# 已寫入：project_gutenberg\儒林外史.txt
# 已寫入：project_gutenberg\楊家將.txt
# 已寫入：project_gutenberg\明鏡公案.txt
# 已寫入：project_gutenberg\五色石.txt
# 已寫入：project_gutenberg\快士傳.txt
# 已寫入：project_gutenberg\飛龍全傳.txt
# 已寫入：project_gutenberg\風月鑒.txt
# 已寫入：project_gutenberg\拾遺記.txt
# 已寫入：project_gutenberg\古詩十九首.txt
# 已寫入：project_gutenberg\金瓶梅.txt
# 已寫入：project_gutenberg\滿江紅.txt
# 已寫入：project_gutenberg\宛如約.txt
# 已寫入：project_gutenberg\歡喜冤家.txt
# 已寫入：project_gutenberg\文子.txt
# 已寫入：project_gutenberg\八段錦.txt
# 已寫入：project_gutenberg\辛棄疾詞選.txt
# 已寫入：project_gutenberg\唐才子傳.txt
# 已寫入：project_gutenberg\楊家將.txt
# 已寫入：project_gutenberg\楊家將.txt
# 已寫入：project_gutenberg\楊家將演義.txt
# 已寫入：project_gutenberg\夜雨秋燈錄.txt
# 已寫入：project_gutenberg\雙鳳奇緣.txt
# 已寫入：project_gutenberg\徐霞客遊記.txt
# 已寫入：project_gutenberg\玉台新詠.txt
# 已寫入：project_gutenberg\申鑒.txt
# 已寫入：project_gutenberg\李太白集.txt
# 已寫入：project_gutenberg\李太白集.txt
# 已寫入：project_gutenberg\蘇洵集.txt
# 已寫入：project_gutenberg\玉梨魂.txt
# 已寫入：project_gutenberg\韓湘子全傳.txt
# 已寫入：project_gutenberg\鬼谷四友志.txt
# 已寫入：project_gutenberg\畫圖緣.txt
# 已寫入：project_gutenberg\方言.txt
# 已寫入：project_gutenberg\漢書.txt
# 已寫入：project_gutenberg\巧聯珠.txt
# 已寫入：project_gutenberg\幻中游.txt
# 已寫入：project_gutenberg\滄浪詩話.txt
# 已寫入：project_gutenberg\顔氏家訓.txt
# 已寫入：project_gutenberg\顔氏家訓.txt
# 已寫入：project_gutenberg\顔氏家訓.txt
# 已寫入：project_gutenberg\顔氏家訓 — Volume 01 and 02.txt
# 已寫入：project_gutenberg\顔氏家訓 — Volume 03 and 04.txt
# 已寫入：project_gutenberg\顔氏家訓 — Volume 05 and 06.txt
# 已寫入：project_gutenberg\顔氏家訓 — Volume 07.txt
# 已寫入：project_gutenberg\竹葉亭雜記.txt
# 已寫入：project_gutenberg\豐收.txt
# 已寫入：project_gutenberg\蘭花夢奇傳.txt
# 已寫入：project_gutenberg\尹文子.txt
# 已寫入：project_gutenberg\關尹子.txt
# 已寫入：project_gutenberg\黃繡球.txt
# 已寫入：project_gutenberg\鄰女語.txt
# 已寫入：project_gutenberg\合浦珠.txt
# 已寫入：project_gutenberg\珍珠舶.txt
# 已寫入：project_gutenberg\子不語.txt
# 已寫入：project_gutenberg\續子不語.txt
# 已寫入：project_gutenberg\隨園詩話.txt
# 已寫入：project_gutenberg\鶯鶯傳.txt
# 已寫入：project_gutenberg\青樓夢.txt
# 已寫入：project_gutenberg\沉沦.txt
# 已寫入：project_gutenberg\滿江紅.txt
# 已寫入：project_gutenberg\耳食錄.txt
# 已寫入：project_gutenberg\桯史.txt
# 已寫入：project_gutenberg\蜃樓志.txt
# 已寫入：project_gutenberg\五鳳吟.txt
# 已寫入：project_gutenberg\警悟鐘.txt
# 已寫入：project_gutenberg\蕩寇志.txt
# 已寫入：project_gutenberg\裨海紀遊.txt
# 已寫入：project_gutenberg\孽海花.txt
# 已寫入：project_gutenberg\幽夢影.txt
# 已寫入：project_gutenberg\幽夢影.txt
# 已寫入：project_gutenberg\幽夢影 — Part 1.txt
# 已寫入：project_gutenberg\幽夢影 — Part 2.txt
# 已寫入：project_gutenberg\西湖夢尋.txt
# 已寫入：project_gutenberg\陶庵夢憶.txt
# 已寫入：project_gutenberg\列仙傳.txt
# 已寫入：project_gutenberg\何典.txt
# 已寫入：project_gutenberg\棋經.txt
# 已寫入：project_gutenberg\括異志.txt
# 已寫入：project_gutenberg\杜騙新書.txt
# 已寫入：project_gutenberg\張載集.txt
# 已寫入：project_gutenberg\傷寒論.txt
# 已寫入：project_gutenberg\朝野僉載.txt
# 已寫入：project_gutenberg\遊仙窟.txt
# 已寫入：project_gutenberg\遊仙窟.txt
# 已寫入：project_gutenberg\花間集.txt
# 已寫入：project_gutenberg\吳越春秋.txt
# 已寫入：project_gutenberg\甌北詩話.txt
# 已寫入：project_gutenberg\明皇雜錄.txt
# 已寫入：project_gutenberg\詩品.txt
# 已寫入：project_gutenberg\詩品.txt
# 已寫入：project_gutenberg\周禮.txt
# 已寫入：project_gutenberg\西湖二集.txt
# 已寫入：project_gutenberg\千字文.txt
# 已寫入：project_gutenberg\千字文.txt
# 已寫入：project_gutenberg\千字文.txt
# 已寫入：project_gutenberg\雞肋編.txt
# 已寫入：project_gutenberg\出師表.txt
# 已寫入：project_gutenberg\牛郎織女傳.txt
# 已寫入：project_gutenberg\中庸 章句.txt
# 已寫入：project_gutenberg\大學 章句.txt
# 已寫入：project_gutenberg\近思錄.txt
# 已寫入：project_gutenberg\近思錄.txt
# 已寫入：project_gutenberg\朱子治家格言.txt
# 已寫入：project_gutenberg\歐遊雜記.txt
# 已寫入：project_gutenberg\樂章集.txt
# 已寫入：project_gutenberg\狐狸緣全傳.txt
# 已寫入：project_gutenberg\清代野记.txt
# 已寫入：project_gutenberg\風流悟.txt
# 已寫入：project_gutenberg\國語.txt
# 已寫入：project_gutenberg\左傳.txt
# 478
